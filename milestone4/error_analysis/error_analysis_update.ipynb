# %%
import pandas as pd

# %%
pd.set_option('display.max_colwidth', None)

filename = "/Users/chloe/Desktop/Block6/lab2/COLX_531_bossy_beaver/data/milestone4/elife_groq_mistral_summary.csv"

df = pd.read_csv(filename)

random_rows = df.sample(1, random_state=42)[['lay_summary', 'groq_mistral_summary']]

print(random_rows)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %% [markdown]
# Comment:
#
# Although both abstracts refer to the role of Sgol2 protein in cell division, their emphasis is different:
#
# The "lay_summary" section focuses on explaining the role of Sgol2 in meiosis, focusing on summarizing the functions of Sgol2, including helping to align chromosomes, closing checkpoints, regulating enzyme activity, etc., and its key role in ensuring chromosome allocation.
#
# The section "groq_mistral_summary" describes in more detail the role of Sgol2 in mammalian oocytes, especially its interactions with other proteins. It includes how Sgol2 protects chromosome integrity, closes spindle assembly checkpoints, promotes chromosomal bidirectional localization, promotes centromer-microtubules interactions, and Sgol2's interactions with protein phosphatase 2A (PP2A) and Mad2.

# %%
random_rows = df.sample(1, random_state=43)[['lay_summary', 'groq_mistral_summary']]

print(random_rows)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %% [markdown]
# Comment:
#
# Although both abstracts deal with the study of RNA polymerase II CTD, their focus is slightly different:
#
# The "lay_summary" simplifies the transcription process, highlighting RNA polymerase II's role in converting DNA to mRNA, focusing on a key component, the carboxy-terminal domain (CTD), and its amino acid modifications, notably lysine-7 methylation, which fine-tunes enzyme activity.
#
# In contrast, the "groq_mistral_summary" delves into the complexities of CTD modifications, including lysine-7 methylation's novel role in transcription regulation, underscoring its impact on gene expression and the intricate balance between methylation and acetylation.

# %%
random_rows = df.sample(1, random_state=44)[['lay_summary', 'groq_mistral_summary']]

print(random_rows)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %% [markdown]
# Comment:
#
# Although both abstracts delve into the dynamics of Ras proteins and their role in cell signaling, their emphasis differs significantly:
#
# The "lay_summary" presents a clear overview of how Ras proteins, crucial for transmitting signals within cells, must cluster at specific membrane sites to relay signals effectively. It discusses the use of advanced microscopy techniques to track Ras movement, revealing a three-state mobility pattern (fast, intermediate, and immobile) and the existence of specialized domains that regulate this mobility. This summary underscores the discovery of 'immobilization' and 'intermediate' domains, highlighting their roles in guiding and clustering Ras molecules, which could be pivotal in understanding cell signaling mechanisms and cancer-related mutations.
#
# In contrast, the "groq_mistral_summary" provides a detailed analysis of the spatial regulation of Ras signaling, specifically focusing on the KRasG12D mutant in U2OS cells. It elaborates on the use of spt-PALM and trajectory analysis to discover that KRasG12D's movement is governed by nested membrane nanodomains, dictating its diffusion and trafficking patterns. The study unveils the sizes and lifetimes of these domains and their influence on KRasG12D's behavior, proposing a non-equilibrium steady state model for Ras dynamics. This summary highlights the study's contribution to our understanding of membrane organization's impact on signaling molecule behavior, suggesting a new model for the role of membrane nanodomains in Ras multimer formation and signaling.

# %%
random_rows = df.sample(1, random_state=45)[['lay_summary', 'groq_mistral_summary']]

print(random_rows)
# Out:
#                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                                       
# ...

# %% [markdown]
# Comments:
#
# Both summaries delve into the behavior of AMPA receptors (AMPARs) at neuron synapses, essential for memory and learning, yet from distinct angles and with different methodologies.
#
# The "lay_summary" simplifies the exploration of memory formation mechanisms, focusing on the AMPA receptors' role in synaptic strengthening. It introduces a novel quantum dot technique to visualize AMPARs moving within the synaptic cleft, challenging the prior assumption that AMPARs accumulate outside synapses before integrating into the synaptic membrane. This insight shifts our understanding of how synaptic connections are reinforced, potentially illuminating new aspects of memory processes.
#
# On the other hand, the "groq_mistral_summary" provides a detailed account of a study using super-resolution microscopy to track AMPAR movement in relation to post-synaptic densities (PSDs). This research contrasts different fluorescent markers to demonstrate that most AMPARs operate within confined nanodomains inside PSDs, offering a new perspective that these receptors primarily function within synapses rather than accumulating outside. This advanced imaging study contributes to our understanding of synaptic plasticity's cellular underpinnings, highlighting a structured yet dynamic synaptic environment crucial for learning and memory.
